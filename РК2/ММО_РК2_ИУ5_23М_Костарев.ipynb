# %% [markdown]
# # Рубежный контроль 2
#
# **Тема**: Методы обработки текстов
#
# **Курс**: Методы машинного обучения
#
# **Группа**: ИУ5-23М
#
# **Студент**: Костарев А. П.
#
# **Классификатор 1 (согласно варианту)**: LinearSVC
#
# **Классификатор 2 (согласно варианту)**: LogisticRegression

# %% [markdown]
# ## Задание
#
# Необходимо решить задачу классификации текстов на основе любого выбранного Вами датасета (кроме примера, который рассматривался в лекции). Классификация может быть бинарной или многоклассовой. Целевой признак из выбранного Вами датасета может иметь любой физический смысл, примером является задача анализа тональности текста.
#
# Необходимо сформировать два варианта векторизации признаков - на основе CountVectorizer и на основе TfidfVectorizer.

# %% [markdown]
# ## Выполнение задания

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import time

# %%
# Загрузка данных
df = pd.read_csv('Elon_musk_articles.csv')

# %%
df.head(10)
# Out:
#                                 _id  \
# 0  aeb7516f5d92102a7fb065bb979d1ca9
# 1  308ad55c4f65e17d45dda50f96999d79
# 2  0e81aa01030edd3259773ee0e2b0a7ed
# 3  cdf608587b9acbaf5ca2f12066a342eb
# 4  12ac1ecc50462b01a84e1fe7c773e46f
# 5  65e9c8388c7f495438b57104bb8fcd05
# 6  4d7a437f56a9307df00ee351d7f1c040
# 7  1b05458847d3986365c814c7760584d9
# 8  d4105fbd7edd90160d7075f7430e908c
# 9  82f5597482d9ee48734343c0a8bd081f
#
#                                                title             author  \
# 0  How Elon Musk, Jack Dorsey, and Parag Agrawal ...          The Verge
# 1  Advice to your younger self? Elon musk, stops,...       Mallika Soni
# 2  You're free to tweet: Messages reveal Elon Mus...       Mallika Soni
# 3  The Complicated Truth About Elon Musk's Mom An...         Nadine Tag
# 4  Elon Musk's texts with Jack Dorsey and Parag A...            K. Bell
# 5  Chat Between Elon Musk and Twitter Executives ...         Aditi Bali
# 6  The Twitter Deal was Supposed to be Joined in ...         Mehdi Zare
# 7  Elon Musk doesn't love being a leader: Text me...                NaN
# 8  Elon Musk Was Mulling Creating a Blockchain-Ba...  Sandali Handagama
# 9  Streaming Fatigue? Here's How to Quickly and E...    Tri-City Herald
#
#      published_date                                               link  \
# 0  30-09-2022 00:30  https://www.newsbreak.com/news/2766864647680/h...
# 1  01-10-2022 05:46  https://www.hindustantimes.com/world-news/elon...
# 2  01-10-2022 02:20  https://www.hindustantimes.com/world-news/elon...
# 3  02-10-2022 17:26  https://www.thethings.com/elon-musks-mom-maye-...
# 4  30-09-2022 00:02  https://www.newsbreak.com/news/2766803421377/e...
# 5  30-09-2022 21:06  https://techstory.in/chat-between-elon-musk-an...
# 6  30-09-2022 11:26  https://www.newsbreak.com/news/2767413765593/t...
# 7  01-10-2022 04:26  https://www.indiatoday.in/technology/story/tex...
# 8  30-09-2022 11:18  https://www.newsbreak.com/news/2767432983421/e...
# 9  30-09-2022 17:13  https://www.newsbreak.com/news/2767859228939/s...
#
#             clean_url                                            excerpt  \
# 0       newsbreak.com  Elon Musk's deposition for the Twitter v. Musk...
# 1  hindustantimes.com  Elon Musk: In an event devoted to robots and t...
# 2  hindustantimes.com  Elon Musk-Twitter Trial: Elon Musk and Twitter...
# 3       thethings.com  Elon Musk learned that being a billionaire doe...
# 4       newsbreak.com  A tranche of Elon Musk's private messages have...
# 5        techstory.in  According to recent reports, chats between Elo...
# 6       newsbreak.com  According to a series of text messages that we...
# 7       indiatoday.in  Hundreds of text messages between Elon Musk an...
# 8       newsbreak.com  "I think a new social media company is needed ...
# 9       newsbreak.com  Streaming powerhouse Netflix once had the mark...
#
#                                              summary              rights  \
# 0  #Linus Elon Musk#Linus Business#Business Leade...       newsbreak.com
# 1  Published on Oct 01, 2022 11:16 AM IST\n\n \n\...  hindustantimes.com
# 2  Messages between Tesla chief Elon Musk and imp...  hindustantimes.com
# 3  Everyone knows Elon Musk as a pioneer, a busin...       thethings.com
# 4  #Linus Business#Business Leadership#Linus Comp...       newsbreak.com
# 5  According to recent reports, chats between Elo...        techstory.in
# 6  #Internal Communications#Silicon Valley#Busine...       newsbreak.com
# 7  Text messages between Elon Musk and key figure...       indiatoday.in
# 8  Terms of UsePrivacy PolicyDo Not Sell My InfoH...       newsbreak.com
# 9  Elon Musk on Tuesday revived his offer to buy ...       newsbreak.com
#
#    article_rank  topic country language                    authors  \
# 0          4828   news      PH       en    Adi Robertson,The Verge
# 1           980  world      IN       en               Mallika Soni
# 2           980   news      IN       en               Mallika Soni
# 3         14092   news      US       en                 Nadine Tag
# 4          4828   news      PH       en                    K. Bell
# 5         23310   news      IN       en                 Aditi Bali
# 6          4828   news      PH       en                 Mehdi Zare
# 7          1817   news      IN       en                        NaN
# 8          4828   news      PH       en          Sandali Handagama
# 9          4828   news      PH       en  NewsBreak,Tri-City Herald
#
#                                                media twitter_account  \
# 0  https://img.particlenews.com/img/id/27ZFhy_0iF...      @newsbreak
# 1  https://images.hindustantimes.com/img/2022/10/...       @httweets
# 2  https://images.hindustantimes.com/img/2022/10/...       @httweets
# 3  https://static0.thethingsimages.com/wordpress/...   @Thethingscom
# 4  https://img.particlenews.com/img/id/0KVfPN_0iF...      @newsbreak
# 5  https://techstory.in/wp-content/uploads/2022/0...     techstoryin
# 6  https://img.particlenews.com/img/id/0zDeUa_0iG...      @newsbreak
# 7  https://akm-img-a-in.tosshub.com/indiatoday/im...     @indiatoday
# 8  https://img.particlenews.com/img/id/3uExP5_0iG...      @newsbreak
# 9  https://img.particlenews.com/img/id/0fIYy9_0iG...      @newsbreak
#
#    article_score
# 0      23.075157
# 1      23.064392
# 2      22.901016
# 3      22.876207
# 4      22.777958
# 5      22.714160
# 6      22.673359
# 7      22.672802
# 8      22.655766
# 9      22.566383

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              5000 non-null   object
#  1   title            5000 non-null   object
#  2   author           4438 non-null   object
#  3   published_date   5000 non-null   object
#  4   link             5000 non-null   object
#  5   clean_url        5000 non-null   object
#  6   excerpt          4962 non-null   object
#  7   summary          4986 non-null   object
#  8   rights           4966 non-null   object
#  9   article_rank     5000 non-null   int64
#  10  topic            5000 non-null   object
#  11  country          5000 non-null   object
#  12  language         5000 non-null   object
#  13  authors          4438 non-null   object
#  14  media            4962 non-null   object
#  15  twitter_account  3538 non-null   object
#  16  article_score    5000 non-null   float64
# dtypes: float64(1), int64(1), object(15)
# memory usage: 664.2+ KB

# %%
# проверим пропуски в данных и устраним их
na_mask = df.isna()
na_counts = na_mask.sum()
na_counts
# Out:
# _id                   0
# title                 0
# author              562
# published_date        0
# link                  0
# clean_url             0
# excerpt              38
# summary              14
# rights               34
# article_rank          0
# topic                 0
# country               0
# language              0
# authors             562
# media                38
# twitter_account    1462
# article_score         0
# dtype: int64

# %%
df.dropna(inplace=True)
na_mask = df.isna()
na_counts = na_mask.sum()
na_counts
# Out:
# _id                0
# title              0
# author             0
# published_date     0
# link               0
# clean_url          0
# excerpt            0
# summary            0
# rights             0
# article_rank       0
# topic              0
# country            0
# language           0
# authors            0
# media              0
# twitter_account    0
# article_score      0
# dtype: int64

# %%
# Разделим набор данных на обучающую и тестувую выборки
X, Y = df['summary'], df['topic']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

time_arr = []

# %%
# векторизация признаков с помощью CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_test_counts = count_vect.transform(X_test)

# %%
# векторизация признаков с помощью TfidfVectorizer
tfidf_vect = TfidfVectorizer()
X_train_tfidf = tfidf_vect.fit_transform(X_train)
X_test_tfidf = tfidf_vect.transform(X_test)

# %%
# Произведем обучения двух классификаторов (по варианту) для CountVectorizer

# LinearSVC
gbc = LinearSVC()
start_time = time.time()
gbc.fit(X_train_counts, y_train)
train_time = time.time() - start_time
time_arr.append(train_time)
pred_gbc_counts = gbc.predict(X_test_counts)
print("Точность (CountVectorizer + LinearSVC):", accuracy_score(y_test, pred_gbc_counts))

# Logistic Regression
lr = LogisticRegression(max_iter=2000)
start_time = time.time()
lr.fit(X_train_counts, y_train)
train_time = time.time() - start_time
time_arr.append(train_time)
pred_lr_counts = lr.predict(X_test_counts)
print("Точность (CountVectorizer + LogisticRegression):", accuracy_score(y_test, pred_lr_counts))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Точность (CountVectorizer + LinearSVC): 0.7315541601255887
# Точность (CountVectorizer + LogisticRegression): 0.7770800627943485

# %%
# Произведем обучения вдух классификаторов (по варианту) для TfidfVectorizer

# LinearSVC
gbc = LinearSVC()
start_time = time.time()
gbc.fit(X_train_tfidf, y_train)
train_time = time.time() - start_time
time_arr.append(train_time)
pred_gbc_tfidf = gbc.predict(X_test_tfidf)
print("Точность (TfidfVectorizer + LinearSVC):", accuracy_score(y_test, pred_gbc_tfidf))

# Logistic Regression
lr = LogisticRegression(max_iter=2000)
start_time = time.time()
lr.fit(X_train_tfidf, y_train)
train_time = time.time() - start_time
time_arr.append(train_time)
pred_lr_tfidf = lr.predict(X_test_tfidf)
print("Точность (TfidfVectorizer + LogisticRegression):", accuracy_score(y_test, pred_lr_tfidf))
# Out:
# Точность (TfidfVectorizer + LinearSVC): 0.8037676609105181
# Точность (TfidfVectorizer + LogisticRegression): 0.8084772370486656

# %%
from tabulate import tabulate

data = [
    ["(CountVectorizer + LogisticRegression)", accuracy_score(y_test, pred_lr_counts), time_arr[0]],
    ["(CountVectorizer + LinearSVC)", accuracy_score(y_test, pred_gbc_counts), time_arr[1]],
    ["(TfidfVectorizer + LogisticRegression)", accuracy_score(y_test, pred_lr_tfidf), time_arr[2]],
    ["(TfidfVectorizer + LinearSVC)", accuracy_score(y_test, pred_gbc_tfidf), time_arr[3]]
]

sorted_data = sorted(data, key=lambda x: x[1], reverse=True)

# Вывод отсортированных данных в виде таблицы
print(tabulate(sorted_data, ['Связка','Точность валидации', 'Время обучения'], tablefmt="grid"))
# Out:
# +----------------------------------------+----------------------+------------------+
# | Связка                                 |   Точность валидации |   Время обучения |
# +========================================+======================+==================+
# | (TfidfVectorizer + LogisticRegression) |             0.808477 |          1.77126 |
# +----------------------------------------+----------------------+------------------+
# | (TfidfVectorizer + LinearSVC)          |             0.803768 |         84.5727  |
# +----------------------------------------+----------------------+------------------+
# | (CountVectorizer + LogisticRegression) |             0.77708  |          4.12995 |
# +----------------------------------------+----------------------+------------------+
# | (CountVectorizer + LinearSVC)          |             0.731554 |         52.7793  |
# +----------------------------------------+----------------------+------------------+
